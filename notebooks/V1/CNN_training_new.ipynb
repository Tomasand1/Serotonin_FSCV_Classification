# %%
#Neural network training with syntethic in vivo dopamine and serotonin signals. 
import tensorflow as tf
import os
import keras
import pandas as pd
from tensorflow.keras import datasets, layers, models, utils, regularizers
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import numpy as np
from sklearn.model_selection import train_test_split
print(tf.__version__)
from sklearn.decomposition import PCA
from tensorflow.keras.layers import Activation, Dense, LeakyReLU
from sklearn.model_selection import KFold
import keras_tuner as kt
# Out:
# 2.7.0

# %%
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import MultiLabelBinarizer


def generate_class_weights(class_series, multi_class=True, one_hot_encoded=False):
  if multi_class:
    # If class is one hot encoded, transform to categorical labels to use compute_class_weight   
    if one_hot_encoded:
      class_series = np.argmax(class_series, axis=1)
  
    # Compute class weights with sklearn method
    class_labels = np.unique(class_series)
    class_weights = compute_class_weight(class_weight='balanced', classes=class_labels, y=class_series)
    return dict(zip(class_labels, class_weights))
  else:
    # It is neccessary that the multi-label values are one-hot encoded
    mlb = None
    if not one_hot_encoded:
      mlb = MultiLabelBinarizer()
      class_series = mlb.fit_transform(class_series)

    n_samples = len(class_series)
    n_classes = len(class_series[0])

    # Count each class frequency
    class_count = [0] * n_classes
    for classes in class_series:
        for index in range(n_classes):
            if classes[index] != 0:
                class_count[index] += 1
    
    # Compute class weights using balanced method
    class_weights = [n_samples / (n_classes * freq) if freq > 0 else 1 for freq in class_count]
    class_labels = range(len(class_weights)) if mlb is None else mlb.classes_
    return dict(zip(class_labels, class_weights))

# %%
#Load colorplot datasets. 
X = np.load('data.npz')['a'].reshape(5179, 200, 100, 1)

#Creating the labels. 
y = pd.read_excel('Labels_v1.xlsx', header = None).values

#Shuffling the dataset.
shuffler = np.random.permutation(len(y))
X = X[shuffler]
y = y[shuffler]
class_weights = generate_class_weights(y[:,0])

# %%
#Define a function to plot the loss per epoch 
def plot_loss(history):
    plt.figure()
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Error')
    plt.legend()
    plt.grid(True)
    plt.figure()
    plt.plot(history.history['accuracy'], label="acc")
    plt.plot(history.history['val_accuracy'], label="val.acc")
    plt.xlabel('Epoch')
    plt.ylabel('Acc.')
    
    #Define the model again with the optimal params.
    
def build_and_compile_model(): 
    model = models.Sequential()
    #model.add(layers.GaussianNoise(stddev=0.25,input_shape=(200, 100, 1)))
    model.add(layers.LayerNormalization(axis = [1, 2, 3], input_shape=(200, 100, 1)))
    model.add(layers.Conv2D(100, (3, 3), activation='relu', kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(l=0.01)))
    model.add(layers.MaxPooling2D((3, 3)))
    model.add(layers.Conv2D(10, (3, 3), activation='relu', kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(l=0.01)))
    model.add(layers.MaxPooling2D((3, 3)))
    model.add(layers.Conv2D(10, (3, 3), activation='relu', kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(l=0.01)))
    #model.add(layers.Conv2D(10, (3, 3), activation='relu', kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(l=0.01)))
    #model.add(layers.Conv2D(10, (3, 3), activation='relu', kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(l=0.01)))
    #model.add(layers.Conv2D(10, (3, 3), activation='relu', kernel_initializer='he_normal', kernel_regularizer=regularizers.l2(l=0.01)))
    model.add(layers.Flatten())
    model.add(layers.Dense(1000, activation='relu'))
    #model.add(layers.Dropout(0.2))
    model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    #model.add(layers.Dense(100, activation='relu'))
    #model.add(layers.Dropout(0.2))
    model.add(layers.Dense(1))
    model.summary()
    model.compile(loss=[tf.keras.losses.BinaryCrossentropy(from_logits=True)], optimizer=tf.keras.optimizers.Adam(0.0001), metrics=['accuracy'])
    return model

# %%
inputs = X
targets = y

# Define the K-fold Cross Validator
num_folds = 5
kfold = KFold(n_splits=num_folds, shuffle=True)
# K-fold Cross Validation model evaluation
fold_no = 1
for train, test in kfold.split(inputs, targets):
    cnn = build_and_compile_model()
    #Train the model
    history = cnn.fit(
    inputs[train], targets[train],                         # changed expression for test features and labels
    validation_split=0.25,                                 # I removed validation for k-fold cross validation
    verbose=1, epochs=25, 
    class_weight = class_weights)
    newfig = plt.figure()
    plot_loss(history)
    #Prediction of the validation dataset 
    test_predictions = cnn.predict(inputs[test]).flatten()
    fold_no = fold_no + 1
# Out:
# 2022-02-28 15:41:15.421011: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-02-28 15:41:15.421157: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1 Max
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer_normalization (LayerN  (None, 200, 100, 1)      40000
#  ormalization)
#
#  conv2d (Conv2D)             (None, 198, 98, 100)      1000
#
#  max_pooling2d (MaxPooling2D  (None, 66, 32, 100)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 30, 10)        9010
#
#  max_pooling2d_1 (MaxPooling  (None, 21, 10, 10)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 19, 8, 10)         910
#
#  flatten (Flatten)           (None, 1520)              0
#
#  dense (Dense)               (None, 1000)              1521000
#
#  dense_1 (Dense)             (None, 100)               100100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 1,682,221
# Trainable params: 1,682,221
# Non-trainable params: 0
# _________________________________________________________________
# 2022-02-28 15:41:15.999895: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/25
# 2022-02-28 15:41:16.340130: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 98/98 [==============================] - ETA: 0s - loss: 1.0584 - accuracy: 0.7943
# 2022-02-28 15:41:28.250919: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 98/98 [==============================] - 13s 100ms/step - loss: 1.0584 - accuracy: 0.7943 - val_loss: 2.6750 - val_accuracy: 0.8533
# Epoch 2/25
# 98/98 [==============================] - 9s 87ms/step - loss: -4.0241 - accuracy: 0.7815 - val_loss: 2.6510 - val_accuracy: 0.8726
# Epoch 3/25
# 98/98 [==============================] - 8s 86ms/step - loss: -6.2051 - accuracy: 0.8294 - val_loss: 4.7160 - val_accuracy: 0.6998
# Epoch 4/25
# 98/98 [==============================] - 8s 86ms/step - loss: -19.7107 - accuracy: 0.7477 - val_loss: 2.9443 - val_accuracy: 0.8755
# Epoch 5/25
# 98/98 [==============================] - 8s 86ms/step - loss: -50.9051 - accuracy: 0.7821 - val_loss: 3.0079 - val_accuracy: 0.8127
# Epoch 6/25
# 98/98 [==============================] - 8s 85ms/step - loss: -82.8794 - accuracy: 0.7580 - val_loss: 19.8119 - val_accuracy: 0.6969
# Epoch 7/25
# 98/98 [==============================] - 9s 87ms/step - loss: -196.5332 - accuracy: 0.7554 - val_loss: 22.8840 - val_accuracy: 0.7471
# Epoch 8/25
# 98/98 [==============================] - 8s 85ms/step - loss: -398.6117 - accuracy: 0.7631 - val_loss: 28.4396 - val_accuracy: 0.7597
# Epoch 9/25
# 98/98 [==============================] - 8s 86ms/step - loss: -718.5589 - accuracy: 0.7187 - val_loss: 38.7974 - val_accuracy: 0.7799
# Epoch 10/25
# 98/98 [==============================] - 8s 86ms/step - loss: -1232.3839 - accuracy: 0.7271 - val_loss: 37.6790 - val_accuracy: 0.8639
# Epoch 11/25
# 98/98 [==============================] - 8s 86ms/step - loss: -1993.0204 - accuracy: 0.7132 - val_loss: 85.0008 - val_accuracy: 0.6766
# Epoch 12/25
# 98/98 [==============================] - 9s 87ms/step - loss: -2989.1084 - accuracy: 0.7853 - val_loss: 55.6007 - val_accuracy: 0.5743
# Epoch 13/25
# 98/98 [==============================] - 9s 88ms/step - loss: -4678.4019 - accuracy: 0.6997 - val_loss: 57.1489 - val_accuracy: 0.7693
# Epoch 14/25
# 98/98 [==============================] - 8s 85ms/step - loss: -6424.0503 - accuracy: 0.7499 - val_loss: 658.7568 - val_accuracy: 0.6776
# Epoch 15/25
# 98/98 [==============================] - 8s 86ms/step - loss: -9665.9463 - accuracy: 0.6318 - val_loss: 203.4691 - val_accuracy: 0.7799
# Epoch 16/25
# 98/98 [==============================] - 8s 86ms/step - loss: -12806.9756 - accuracy: 0.7110 - val_loss: 666.2134 - val_accuracy: 0.7432
# Epoch 17/25
# 98/98 [==============================] - 8s 86ms/step - loss: -19016.3184 - accuracy: 0.7625 - val_loss: 508.5778 - val_accuracy: 0.7905
# Epoch 18/25
# 98/98 [==============================] - 8s 86ms/step - loss: -27056.9082 - accuracy: 0.7158 - val_loss: 611.7099 - val_accuracy: 0.6824
# Epoch 19/25
# 98/98 [==============================] - 8s 87ms/step - loss: -36128.5820 - accuracy: 0.7486 - val_loss: 2876.5493 - val_accuracy: 0.4025
# Epoch 20/25
# 98/98 [==============================] - 8s 85ms/step - loss: -47754.0781 - accuracy: 0.6791 - val_loss: 801.1138 - val_accuracy: 0.8050
# Epoch 21/25
# 98/98 [==============================] - 8s 87ms/step - loss: -62008.6875 - accuracy: 0.7126 - val_loss: 3518.2407 - val_accuracy: 0.5830
# Epoch 22/25
# 98/98 [==============================] - 8s 86ms/step - loss: -83053.8906 - accuracy: 0.7274 - val_loss: 2560.4543 - val_accuracy: 0.3514
# Epoch 23/25
# 98/98 [==============================] - 8s 85ms/step - loss: -108274.9219 - accuracy: 0.7177 - val_loss: 6722.0093 - val_accuracy: 0.6931
# Epoch 24/25
# 98/98 [==============================] - 8s 86ms/step - loss: -139909.6562 - accuracy: 0.7061 - val_loss: 2666.8186 - val_accuracy: 0.5705
# Epoch 25/25
# 98/98 [==============================] - 8s 87ms/step - loss: -175803.9844 - accuracy: 0.6830 - val_loss: 6571.2070 - val_accuracy: 0.7654
# 2022-02-28 15:44:51.783862: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer_normalization_1 (Laye  (None, 200, 100, 1)      40000
#  rNormalization)
#
#  conv2d_3 (Conv2D)           (None, 198, 98, 100)      1000
#
#  max_pooling2d_2 (MaxPooling  (None, 66, 32, 100)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 30, 10)        9010
#
#  max_pooling2d_3 (MaxPooling  (None, 21, 10, 10)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 19, 8, 10)         910
#
#  flatten_1 (Flatten)         (None, 1520)              0
#
#  dense_4 (Dense)             (None, 1000)              1521000
#
#  dense_5 (Dense)             (None, 100)               100100
#
#  dense_6 (Dense)             (None, 100)               10100
#
#  dense_7 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 1,682,221
# Trainable params: 1,682,221
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2022-02-28 15:44:52.529896: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 98/98 [==============================] - ETA: 0s - loss: 2.9190 - accuracy: 0.8008
# 2022-02-28 15:45:00.843813: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 98/98 [==============================] - 9s 87ms/step - loss: 2.9190 - accuracy: 0.8008 - val_loss: 2.6972 - val_accuracy: 0.8784
# Epoch 2/25
# 98/98 [==============================] - 8s 83ms/step - loss: -0.0652 - accuracy: 0.7995 - val_loss: 2.7029 - val_accuracy: 0.8793
# Epoch 3/25
# 98/98 [==============================] - 9s 88ms/step - loss: -0.7960 - accuracy: 0.7998 - val_loss: 2.7558 - val_accuracy: 0.8716
# Epoch 4/25
# 98/98 [==============================] - 8s 84ms/step - loss: -3.3845 - accuracy: 0.7741 - val_loss: 3.6480 - val_accuracy: 0.7365
# Epoch 5/25
# 98/98 [==============================] - 8s 85ms/step - loss: -11.0206 - accuracy: 0.7824 - val_loss: 3.9516 - val_accuracy: 0.8320
# Epoch 6/25
# 98/98 [==============================] - 8s 86ms/step - loss: -31.0486 - accuracy: 0.7490 - val_loss: 3.3787 - val_accuracy: 0.8986
# Epoch 7/25
# 98/98 [==============================] - 8s 85ms/step - loss: -64.7610 - accuracy: 0.7728 - val_loss: 9.7488 - val_accuracy: 0.7751
# Epoch 8/25
# 98/98 [==============================] - 8s 84ms/step - loss: -145.7499 - accuracy: 0.7193 - val_loss: 17.3352 - val_accuracy: 0.7442
# Epoch 9/25
# 98/98 [==============================] - 8s 85ms/step - loss: -266.8344 - accuracy: 0.7863 - val_loss: 36.4306 - val_accuracy: 0.7288
# Epoch 10/25
# 98/98 [==============================] - 8s 85ms/step - loss: -582.8661 - accuracy: 0.7396 - val_loss: 12.9476 - val_accuracy: 0.8012
# Epoch 11/25
# 98/98 [==============================] - 8s 86ms/step - loss: -946.5372 - accuracy: 0.7564 - val_loss: 305.8459 - val_accuracy: 0.4604
# Epoch 12/25
# 98/98 [==============================] - 8s 84ms/step - loss: -1303.1262 - accuracy: 0.6630 - val_loss: 123.0632 - val_accuracy: 0.7500
# Epoch 13/25
# 98/98 [==============================] - 8s 85ms/step - loss: -2405.4351 - accuracy: 0.7168 - val_loss: 40.7304 - val_accuracy: 0.8755
# Epoch 14/25
# 98/98 [==============================] - 8s 84ms/step - loss: -3760.0220 - accuracy: 0.7483 - val_loss: 836.4575 - val_accuracy: 0.5502
# Epoch 15/25
# 98/98 [==============================] - 8s 84ms/step - loss: -5526.2085 - accuracy: 0.6582 - val_loss: 517.8818 - val_accuracy: 0.7355
# Epoch 16/25
# 98/98 [==============================] - 8s 85ms/step - loss: -8763.4385 - accuracy: 0.7325 - val_loss: 407.6275 - val_accuracy: 0.8031
# Epoch 17/25
# 98/98 [==============================] - 8s 85ms/step - loss: -12929.5723 - accuracy: 0.7522 - val_loss: 963.8929 - val_accuracy: 0.7490
# Epoch 18/25
# 98/98 [==============================] - 8s 84ms/step - loss: -18482.1914 - accuracy: 0.7229 - val_loss: 794.1364 - val_accuracy: 0.7934
# Epoch 19/25
# 98/98 [==============================] - 8s 84ms/step - loss: -27669.8223 - accuracy: 0.7377 - val_loss: 604.8806 - val_accuracy: 0.6863
# Epoch 20/25
# 98/98 [==============================] - 9s 87ms/step - loss: -37128.1953 - accuracy: 0.6604 - val_loss: 3540.6328 - val_accuracy: 0.7288
# Epoch 21/25
# 98/98 [==============================] - 8s 85ms/step - loss: -50025.1875 - accuracy: 0.7580 - val_loss: 2487.6902 - val_accuracy: 0.7220
# Epoch 22/25
# 98/98 [==============================] - 9s 88ms/step - loss: -69786.1172 - accuracy: 0.7425 - val_loss: 1398.9052 - val_accuracy: 0.8407
# Epoch 23/25
# 98/98 [==============================] - 8s 84ms/step - loss: -92094.5078 - accuracy: 0.6765 - val_loss: 4849.6201 - val_accuracy: 0.7722
# Epoch 24/25
# 98/98 [==============================] - 8s 85ms/step - loss: -121635.7188 - accuracy: 0.7412 - val_loss: 8512.5078 - val_accuracy: 0.6795
# Epoch 25/25
# 98/98 [==============================] - 8s 85ms/step - loss: -161861.6406 - accuracy: 0.7078 - val_loss: 3091.9121 - val_accuracy: 0.8224
# 2022-02-28 15:48:22.055446: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer_normalization_2 (Laye  (None, 200, 100, 1)      40000
#  rNormalization)
#
#  conv2d_6 (Conv2D)           (None, 198, 98, 100)      1000
#
#  max_pooling2d_4 (MaxPooling  (None, 66, 32, 100)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 64, 30, 10)        9010
#
#  max_pooling2d_5 (MaxPooling  (None, 21, 10, 10)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 19, 8, 10)         910
#
#  flatten_2 (Flatten)         (None, 1520)              0
#
#  dense_8 (Dense)             (None, 1000)              1521000
#
#  dense_9 (Dense)             (None, 100)               100100
#
#  dense_10 (Dense)            (None, 100)               10100
#
#  dense_11 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 1,682,221
# Trainable params: 1,682,221
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2022-02-28 15:48:22.770997: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 98/98 [==============================] - ETA: 0s - loss: 2.0700 - accuracy: 0.7815
# 2022-02-28 15:48:31.714111: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 98/98 [==============================] - 10s 93ms/step - loss: 2.0700 - accuracy: 0.7815 - val_loss: 2.6947 - val_accuracy: 0.8784
# Epoch 2/25
# 98/98 [==============================] - 9s 86ms/step - loss: -0.0105 - accuracy: 0.7789 - val_loss: 2.6703 - val_accuracy: 0.8784
# Epoch 3/25
# 98/98 [==============================] - 9s 87ms/step - loss: -1.3515 - accuracy: 0.7197 - val_loss: 2.6999 - val_accuracy: 0.8745
# Epoch 4/25
# 98/98 [==============================] - 8s 85ms/step - loss: -4.4380 - accuracy: 0.8239 - val_loss: 10.5265 - val_accuracy: 0.2017
# Epoch 5/25
# 98/98 [==============================] - 8s 86ms/step - loss: -16.8770 - accuracy: 0.6527 - val_loss: 2.7788 - val_accuracy: 0.8764
# Epoch 6/25
# 98/98 [==============================] - 8s 86ms/step - loss: -23.3163 - accuracy: 0.7113 - val_loss: 7.6194 - val_accuracy: 0.7297
# Epoch 7/25
# 98/98 [==============================] - 8s 84ms/step - loss: -49.6218 - accuracy: 0.8014 - val_loss: 11.4521 - val_accuracy: 0.2896
# Epoch 8/25
# 98/98 [==============================] - 8s 86ms/step - loss: -111.4147 - accuracy: 0.5484 - val_loss: 5.5227 - val_accuracy: 0.8407
# Epoch 9/25
# 98/98 [==============================] - 8s 85ms/step - loss: -174.5823 - accuracy: 0.6756 - val_loss: 28.0826 - val_accuracy: 0.6757
# Epoch 10/25
# 98/98 [==============================] - 8s 85ms/step - loss: -318.8123 - accuracy: 0.7113 - val_loss: 26.1649 - val_accuracy: 0.7288
# Epoch 11/25
# 98/98 [==============================] - 8s 87ms/step - loss: -571.2223 - accuracy: 0.6971 - val_loss: 10.3428 - val_accuracy: 0.8263
# Epoch 12/25
# 98/98 [==============================] - 8s 85ms/step - loss: -812.0412 - accuracy: 0.6485 - val_loss: 41.3108 - val_accuracy: 0.7915
# Epoch 13/25
# 98/98 [==============================] - 9s 87ms/step - loss: -1124.9801 - accuracy: 0.7927 - val_loss: 64.4344 - val_accuracy: 0.3021
# Epoch 14/25
# 98/98 [==============================] - 8s 85ms/step - loss: -1977.3641 - accuracy: 0.6366 - val_loss: 72.9907 - val_accuracy: 0.7577
# Epoch 15/25
# 98/98 [==============================] - 8s 85ms/step - loss: -3254.2588 - accuracy: 0.7184 - val_loss: 26.5570 - val_accuracy: 0.8050
# Epoch 16/25
# 98/98 [==============================] - 8s 86ms/step - loss: -4035.9514 - accuracy: 0.6151 - val_loss: 2328.3999 - val_accuracy: 0.2741
# Epoch 17/25
# 98/98 [==============================] - 8s 86ms/step - loss: -6705.8955 - accuracy: 0.5040 - val_loss: 186.7975 - val_accuracy: 0.6737
# Epoch 18/25
# 98/98 [==============================] - 8s 86ms/step - loss: -8511.9160 - accuracy: 0.7528 - val_loss: 374.1769 - val_accuracy: 0.6429
# Epoch 19/25
# 98/98 [==============================] - 8s 86ms/step - loss: -12725.2500 - accuracy: 0.6447 - val_loss: 280.7110 - val_accuracy: 0.6274
# Epoch 20/25
# 98/98 [==============================] - 9s 88ms/step - loss: -17555.8301 - accuracy: 0.6604 - val_loss: 733.0479 - val_accuracy: 0.6004
# Epoch 21/25
# 98/98 [==============================] - 9s 88ms/step - loss: -24033.5684 - accuracy: 0.7351 - val_loss: 1734.1089 - val_accuracy: 0.6708
# Epoch 22/25
# 98/98 [==============================] - 9s 88ms/step - loss: -33020.5469 - accuracy: 0.7004 - val_loss: 1571.7758 - val_accuracy: 0.6313
# Epoch 23/25
# 98/98 [==============================] - 8s 84ms/step - loss: -45200.5547 - accuracy: 0.7132 - val_loss: 272.3996 - val_accuracy: 0.7905
# Epoch 24/25
# 98/98 [==============================] - 8s 85ms/step - loss: -55618.7695 - accuracy: 0.7116 - val_loss: 19867.7598 - val_accuracy: 0.3446
# Epoch 25/25
# 98/98 [==============================] - 8s 86ms/step - loss: -70821.1719 - accuracy: 0.5285 - val_loss: 2809.5901 - val_accuracy: 0.7403
# 2022-02-28 15:51:54.614525: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer_normalization_3 (Laye  (None, 200, 100, 1)      40000
#  rNormalization)
#
#  conv2d_9 (Conv2D)           (None, 198, 98, 100)      1000
#
#  max_pooling2d_6 (MaxPooling  (None, 66, 32, 100)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 64, 30, 10)        9010
#
#  max_pooling2d_7 (MaxPooling  (None, 21, 10, 10)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 19, 8, 10)         910
#
#  flatten_3 (Flatten)         (None, 1520)              0
#
#  dense_12 (Dense)            (None, 1000)              1521000
#
#  dense_13 (Dense)            (None, 100)               100100
#
#  dense_14 (Dense)            (None, 100)               10100
#
#  dense_15 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 1,682,221
# Trainable params: 1,682,221
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2022-02-28 15:51:55.346414: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 98/98 [==============================] - ETA: 0s - loss: 1.9295 - accuracy: 0.7676
# 2022-02-28 15:52:04.021122: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 98/98 [==============================] - 9s 91ms/step - loss: 1.9295 - accuracy: 0.7676 - val_loss: 3.1605 - val_accuracy: 0.7423
# Epoch 2/25
# 98/98 [==============================] - 8s 87ms/step - loss: 0.8217 - accuracy: 0.8330 - val_loss: 5.6590 - val_accuracy: 0.2616
# Epoch 3/25
# 98/98 [==============================] - 8s 86ms/step - loss: -2.6729 - accuracy: 0.6250 - val_loss: 3.2255 - val_accuracy: 0.7500
# Epoch 4/25
# 98/98 [==============================] - 8s 85ms/step - loss: -4.2193 - accuracy: 0.7052 - val_loss: 7.0956 - val_accuracy: 0.4710
# Epoch 5/25
# 98/98 [==============================] - 8s 86ms/step - loss: -16.7792 - accuracy: 0.6485 - val_loss: 3.1069 - val_accuracy: 0.8485
# Epoch 6/25
# 98/98 [==============================] - 8s 85ms/step - loss: -32.6305 - accuracy: 0.7232 - val_loss: 6.5146 - val_accuracy: 0.7162
# Epoch 7/25
# 98/98 [==============================] - 8s 86ms/step - loss: -67.6687 - accuracy: 0.7541 - val_loss: 10.8320 - val_accuracy: 0.7046
# Epoch 8/25
# 98/98 [==============================] - 8s 84ms/step - loss: -147.5941 - accuracy: 0.7947 - val_loss: 9.3076 - val_accuracy: 0.4064
# Epoch 9/25
# 98/98 [==============================] - 8s 85ms/step - loss: -305.1644 - accuracy: 0.7229 - val_loss: 3.6686 - val_accuracy: 0.8485
# Epoch 10/25
# 98/98 [==============================] - 8s 84ms/step - loss: -458.1117 - accuracy: 0.7988 - val_loss: 109.3592 - val_accuracy: 0.5376
# Epoch 11/25
# 98/98 [==============================] - 8s 85ms/step - loss: -864.8656 - accuracy: 0.6360 - val_loss: 6.1695 - val_accuracy: 0.8436
# Epoch 12/25
# 98/98 [==============================] - 8s 84ms/step - loss: -965.4021 - accuracy: 0.7898 - val_loss: 17.6147 - val_accuracy: 0.3716
# Epoch 13/25
# 98/98 [==============================] - 8s 86ms/step - loss: -1845.8960 - accuracy: 0.7049 - val_loss: 89.5198 - val_accuracy: 0.7799
# Epoch 14/25
# 98/98 [==============================] - 8s 84ms/step - loss: -3037.8425 - accuracy: 0.7251 - val_loss: 32.1011 - val_accuracy: 0.4672
# Epoch 15/25
# 98/98 [==============================] - 8s 86ms/step - loss: -4392.6997 - accuracy: 0.6984 - val_loss: 109.9157 - val_accuracy: 0.8243
# Epoch 16/25
# 98/98 [==============================] - 8s 86ms/step - loss: -6718.2876 - accuracy: 0.7502 - val_loss: 104.5209 - val_accuracy: 0.7925
# Epoch 17/25
# 98/98 [==============================] - 8s 85ms/step - loss: -10274.5957 - accuracy: 0.7193 - val_loss: 114.6119 - val_accuracy: 0.8504
# Epoch 18/25
# 98/98 [==============================] - 8s 84ms/step - loss: -15006.9199 - accuracy: 0.7663 - val_loss: 422.2237 - val_accuracy: 0.8224
# Epoch 19/25
# 98/98 [==============================] - 8s 84ms/step - loss: -22246.0273 - accuracy: 0.7519 - val_loss: 222.5887 - val_accuracy: 0.5849
# Epoch 20/25
# 98/98 [==============================] - 8s 85ms/step - loss: -31499.6094 - accuracy: 0.6875 - val_loss: 305.1409 - val_accuracy: 0.5454
# Epoch 21/25
# 98/98 [==============================] - 9s 87ms/step - loss: -41301.7734 - accuracy: 0.7583 - val_loss: 635.5076 - val_accuracy: 0.8388
# Epoch 22/25
# 98/98 [==============================] - 8s 85ms/step - loss: -58761.8594 - accuracy: 0.7499 - val_loss: 1129.5164 - val_accuracy: 0.7761
# Epoch 23/25
# 98/98 [==============================] - 8s 84ms/step - loss: -80471.4844 - accuracy: 0.7338 - val_loss: 701.2554 - val_accuracy: 0.8407
# Epoch 24/25
# 98/98 [==============================] - 8s 86ms/step - loss: -106076.3750 - accuracy: 0.7358 - val_loss: 4469.5913 - val_accuracy: 0.5077
# Epoch 25/25
# 98/98 [==============================] - 8s 85ms/step - loss: -138844.3906 - accuracy: 0.6830 - val_loss: 2001.2310 - val_accuracy: 0.7876
# 2022-02-28 15:55:25.282636: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer_normalization_4 (Laye  (None, 200, 100, 1)      40000
#  rNormalization)
#
#  conv2d_12 (Conv2D)          (None, 198, 98, 100)      1000
#
#  max_pooling2d_8 (MaxPooling  (None, 66, 32, 100)      0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 64, 30, 10)        9010
#
#  max_pooling2d_9 (MaxPooling  (None, 21, 10, 10)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 19, 8, 10)         910
#
#  flatten_4 (Flatten)         (None, 1520)              0
#
#  dense_16 (Dense)            (None, 1000)              1521000
#
#  dense_17 (Dense)            (None, 100)               100100
#
#  dense_18 (Dense)            (None, 100)               10100
#
#  dense_19 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 1,682,221
# Trainable params: 1,682,221
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2022-02-28 15:55:26.611225: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 98/98 [==============================] - ETA: 0s - loss: 2.8086 - accuracy: 0.8446
# 2022-02-28 15:55:35.766315: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 98/98 [==============================] - 10s 95ms/step - loss: 2.8086 - accuracy: 0.8446 - val_loss: 2.6627 - val_accuracy: 0.9218
# Epoch 2/25
# 98/98 [==============================] - 8s 85ms/step - loss: 2.5990 - accuracy: 0.8993 - val_loss: 2.7504 - val_accuracy: 0.8716
# Epoch 3/25
# 98/98 [==============================] - 9s 89ms/step - loss: 2.4895 - accuracy: 0.9106 - val_loss: 2.6601 - val_accuracy: 0.8726
# Epoch 4/25
# 98/98 [==============================] - 8s 86ms/step - loss: 2.3770 - accuracy: 0.9443 - val_loss: 2.4346 - val_accuracy: 0.9276
# Epoch 5/25
# 98/98 [==============================] - 8s 87ms/step - loss: 2.2897 - accuracy: 0.9505 - val_loss: 2.3817 - val_accuracy: 0.9228
# Epoch 6/25
# 98/98 [==============================] - 8s 86ms/step - loss: 2.1931 - accuracy: 0.9685 - val_loss: 2.3841 - val_accuracy: 0.9073
# Epoch 7/25
# 98/98 [==============================] - 9s 87ms/step - loss: 2.1163 - accuracy: 0.9778 - val_loss: 2.2828 - val_accuracy: 0.9276
# Epoch 8/25
# 98/98 [==============================] - 8s 86ms/step - loss: 2.0381 - accuracy: 0.9868 - val_loss: 2.2326 - val_accuracy: 0.9295
# Epoch 9/25
# 98/98 [==============================] - 9s 87ms/step - loss: 1.9726 - accuracy: 0.9884 - val_loss: 2.2489 - val_accuracy: 0.9025
# Epoch 10/25
# 98/98 [==============================] - 8s 87ms/step - loss: 1.9500 - accuracy: 0.9681 - val_loss: 2.1343 - val_accuracy: 0.9170
# Epoch 11/25
# 98/98 [==============================] - 8s 86ms/step - loss: 1.8639 - accuracy: 0.9894 - val_loss: 2.1415 - val_accuracy: 0.9151
# Epoch 12/25
# 98/98 [==============================] - 8s 85ms/step - loss: 1.8009 - accuracy: 0.9942 - val_loss: 2.0656 - val_accuracy: 0.9199
# Epoch 13/25
# 98/98 [==============================] - 8s 85ms/step - loss: 1.7491 - accuracy: 0.9955 - val_loss: 2.0338 - val_accuracy: 0.9208
# Epoch 14/25
# 98/98 [==============================] - 8s 85ms/step - loss: 1.6931 - accuracy: 0.9968 - val_loss: 1.9771 - val_accuracy: 0.9160
# Epoch 15/25
# 98/98 [==============================] - 8s 86ms/step - loss: 1.6445 - accuracy: 0.9968 - val_loss: 1.9403 - val_accuracy: 0.9218
# Epoch 16/25
# 98/98 [==============================] - 8s 85ms/step - loss: 1.5923 - accuracy: 0.9971 - val_loss: 1.8932 - val_accuracy: 0.9218
# Epoch 17/25
# 98/98 [==============================] - 9s 89ms/step - loss: 1.5459 - accuracy: 0.9968 - val_loss: 1.9580 - val_accuracy: 0.8803
# Epoch 18/25
# 98/98 [==============================] - 8s 86ms/step - loss: 1.5530 - accuracy: 0.9717 - val_loss: 1.7661 - val_accuracy: 0.9228
# Epoch 19/25
# 98/98 [==============================] - 8s 86ms/step - loss: 1.4629 - accuracy: 0.9955 - val_loss: 1.7363 - val_accuracy: 0.9228
# Epoch 20/25
# 98/98 [==============================] - 8s 86ms/step - loss: 1.4181 - accuracy: 0.9968 - val_loss: 1.7074 - val_accuracy: 0.9266
# Epoch 21/25
# 98/98 [==============================] - 8s 85ms/step - loss: 1.3743 - accuracy: 0.9977 - val_loss: 1.6767 - val_accuracy: 0.9295
# Epoch 22/25
# 98/98 [==============================] - 9s 88ms/step - loss: 1.3351 - accuracy: 0.9974 - val_loss: 1.6480 - val_accuracy: 0.9093
# Epoch 23/25
# 98/98 [==============================] - 8s 86ms/step - loss: 1.2942 - accuracy: 0.9977 - val_loss: 1.6047 - val_accuracy: 0.9266
# Epoch 24/25
# 98/98 [==============================] - 8s 86ms/step - loss: 1.2562 - accuracy: 0.9965 - val_loss: 1.5571 - val_accuracy: 0.9286
# Epoch 25/25
# 98/98 [==============================] - 9s 91ms/step - loss: 1.2163 - accuracy: 0.9971 - val_loss: 1.5274 - val_accuracy: 0.9160
# 2022-02-28 15:59:00.137186: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
